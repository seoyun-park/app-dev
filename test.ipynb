# %%
def add(input_value):
    result = input_value + 1
    return result

# %%
# lambda
(lambda a : a + 1)(10)
# Out:
# 11

# %%
name: str = "Alice"
name
name= 10
name
# Out:
# 10

# %%
def say_hello(name: str=""):
    print(f'Hello {name}')

# %%
say_hello('Alice')
# Out:
# Hello Alice

# %%
say_hello(20)
# Out:
# Hello 20

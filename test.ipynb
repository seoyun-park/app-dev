# %%
def add(input_value):
    result = input_value + 1
    return result

# %%
# lambda
(lambda a : a + 1)(10)
# Out:
# 11

# %%
name: str = "Alice"
name
name= 10
name
# Out:
# 10

# %%
def say_hello(name: str=""):
    print(f'Hello {name}')

# %%
say_hello('Alice')
# Out:
# Hello Alice

# %%
say_hello(20)
# Out:
# Hello 20

# %%
# 클래스 정의
class NormalUser:
    name = str ="Alice"

user1 = NormalUser() # 객체 생성 - 생성자 __init__(self)
user1.name = 10
user1.name
# Out:
# 10

# %%
from pydantic import BaseModel

class PydanticUser(BaseModel):
    name:str

user2 = PydanticUser(name = 'baby')
user2.name, type(user2.name)
# Out:
# ('baby', str)

# %%
class UserRegister(BaseModel):
    user_id : int
    username : str 
    email : str 
    is_admin : bool = False

# %%
user = UserRegister(
    user_id=1,
    username="홍길동",
    email="hong@example.com"
)

user
# Out:
# UserRegister(user_id=1, username='홍길동', email='hong@example.com', is_admin=False)

# %%
input_data = {
    "user_id": "1004",    # 문자열로 들어왔지만 int로 자동 변환(Parsing)됩니다.
    "username": "codemaster",
    "email": "code@example.com"
    # is_admin은 생략되었으므로 기본값 False가 적용됩니다.
}

# %%
user1 = UserRegister(**input_data) #언팩킹
user1.user_id , type(user1.user_id)
# Out:
# (1004, int)

# %%
user1.model_dump()
# Out:
# {'user_id': 1004,
#  'username': 'codemaster',
#  'email': 'code@example.com',
#  'is_admin': False}

# %%
import urllib.request

# %%
import requests

# %%
import os
os.getcwd()
os.path.abspath('hello.html')
# Out:
# 'c:\\study\\app-dev\\hello.html'

# %%
file_url = "file:///"+ os.path.abspath('hello.html')
file_url
# Out:
# 'file:///c:\\study\\app-dev\\hello.html'

# %%
with urllib.request.urlopen(file_url) as f:
    html = f.read().decode('utf-8')

print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>martklee's Document</title>
# </head>
# <body>
#     <!--여기는 주석입니다.-->
#     <strong>안녕하세요 저는 지금 매우 졸립니다</strong>
# </body>
# </html>

# %%
import os
os.getcwd()
os.path.abspath('01-status.html')
# Out:
# 'c:\\study\\app-dev\\01-status.html'

# %%
file_url1 = "file:///"+ os.path.abspath('01-status.html')
file_url1
# Out:
# 'file:///c:\\study\\app-dev\\01-status.html'

# %%
# request.get
index_url = "https://finance.naver.com/marketindex/"
res = requests.get(index_url)
print(res.text)
# Out:
# <script language=javascript src="/template/head_js.naver?referer=info.finance.naver.com&menu=marketindex&submenu=market"></script>
# <script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260731153938/js/info/jindo.min.ns.1.5.3.euckr.js"></script>
# <script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20260731153938/js/jindo.1.5.3.element-text-patch.js"></script>
#
#
#
#
# 	<div id="container" style="padding-bottom:0px;">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		<div class="market_include">
# 	<div class="market_data">
# 		<div class="market1">
# 			<div class="title">
# 				<h2 class="h_market1"><span>환전 고시 환율</span></h2>
# 			</div>
# 			<!-- data -->
# 			<div class="data">
# 				<ul class="data_lst" id="exchangeList">
#
#
#
#
#
#
#
#
# 				 	<li class="on">
# 					<a href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" class="head usd" onClick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
with urllib.request.urlopen(file_url1) as ff:
    html = ff.read().decode('utf-8')

print(html)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:1471, in FileHandler.open_local_file(self, req)
#    1470 try:
# -> 1471     stats = os.stat(localfile)
#    1472     size = stats.st_size
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'c:\\study\\app-dev\\01-status.html'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 with urllib.request.urlopen(file_url1) as ff:
#       2     html = ff.read().decode('utf-8')
#       3
#       4 print(html)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\urllib\request.py:187, in urlopen(url, data, timeout, context)
#     185 else:
#     186     opener = _opener
# --> 187 return opener.open(url, data, timeout)
#
# ...

# %%
from pathlib import Path

file_path = Path(r"C:\study\app-dev\01-status.html")

print(file_path)
print("파일 존재 여부:", file_path.exists())

# %%
import httpx
async def fetch_data():
    with httpx.AsyncClient() as client:
        response = await client.get('http://example.com')
        return response.json()

# %%
call_url = "https://api.open-meteo.com/v1/forecast?latitude=36.8&longitude=127.1&current=temperature_2m,relative_humidity_2m&timezone=Asia/Seoul"
call_url
# Out:
# 'https://api.open-meteo.com/v1/forecast?latitude=36.8&longitude=127.1&current=temperature_2m,relative_humidity_2m&timezone=Asia/Seoul'

# %%
params_value= {"latitude": 36.8, "longitude" : 127.1, "current" : "temperature_2m,relative_humidity_2m", "timezone" : 'Asia/Seoul'}

# %%
# requests (1번 방식)
import requests
response = requests.get(call_url) #sync

response.json()
# Out:
# {'latitude': 36.8,
#  'longitude': 127.125,
#  'generationtime_ms': 0.03457069396972656,
#  'utc_offset_seconds': 32400,
#  'timezone': 'Asia/Seoul',
#  'timezone_abbreviation': 'GMT+9',
#  'elevation': 42.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%'},
#  'current': {'time': '2026-08-14T12:15',
#   'interval': 900,
#   'temperature_2m': 28.4,
#   'relative_humidity_2m': 75}}

# %%
# httpx (2번 방식)

only_url = "https://api.open-meteo.com/v1/forecast"
params_value = {
        "latitude": 36.8,
        "longitude": 127.1,
        "current": "temperature_2m,relative_humidity_2m",
        "timezone": "Asia/Seoul",
    }


params_value


import requests
response = requests.get(only_url,
                        params=params_value,
                        timeout=5) #sync


response.json()
# Out:
# {'latitude': 36.8,
#  'longitude': 127.125,
#  'generationtime_ms': 0.05137920379638672,
#  'utc_offset_seconds': 32400,
#  'timezone': 'Asia/Seoul',
#  'timezone_abbreviation': 'GMT+9',
#  'elevation': 42.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%'},
#  'current': {'time': '2026-08-14T12:15',
#   'interval': 900,
#   'temperature_2m': 28.4,
#   'relative_humidity_2m': 75}}

# %%
# httpx

import httpx

async def get_weather():
    async with httpx.AsyncClient(timeout=5) as client:
        response  = await client.get(only_url, params = params_value)

    data = response.json()
    

    return data

# %%
result = await get_weather()
print(result)
# Out:
# {'latitude': 36.8, 'longitude': 127.125, 'generationtime_ms': 0.0680685043334961, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 42.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'relative_humidity_2m': '%'}, 'current': {'time': '2026-08-14T12:30', 'interval': 900, 'temperature_2m': 28.6, 'relative_humidity_2m': 73}}
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_14724\2794117408.py:1: RuntimeWarning: coroutine 'get_weather' was never awaited
#   result = await get_weather()
# ...
